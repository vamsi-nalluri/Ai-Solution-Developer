# %%
import tensorflow
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPool2D
from keras.layers import Activation
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Dropout

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import array_to_img,img_to_array,load_img
#create an image instance of the ImageDataGenerator
train_datagen=ImageDataGenerator(rotation_range=40,
                                 width_shift_range=0.25,
                                height_shift_range=0.25,
                                shear_range=0.2,
                                zoom_range=0.2,
                                rescale=1./255,
                                horizontal_flip=True,
                                fill_mode='nearest')
test_datagen=ImageDataGenerator(rescale=1./255)

#Train data fetching from the directory of images
batch_size=16
train_data=train_datagen.flow_from_directory('C:/Users/vamsi/Jupiternotebook/AI Solution Development/NN/Results/CNN/train',
                                             target_size=(150,150),batch_size=batch_size,class_mode='categorical')

#Test data fetching from the directory of images
test_data=test_datagen.flow_from_directory('C:/Users/vamsi/Jupiternotebook/AI Solution Development/NN/Results/CNN/test',
                                           target_size=(150,150),batch_size=batch_size,class_mode='categorical')
# Out:
# Found 2023 images belonging to 2 classes.
# Found 99 images belonging to 2 classes.

# %%
model=Sequential()

#1st convolution layer
model.add(Conv2D(32,(3,3),input_shape=(150,150,3),activation='relu'))
model.add(MaxPool2D(pool_size=(2,2)))

#2nd convolution layer
model.add(Conv2D(64,(3,3),input_shape=(150,150,3),activation='relu'))
model.add(MaxPool2D(pool_size=(2,2)))

#3rd convolution layer
model.add(Conv2D(32,(3,3)))
model.add(MaxPool2D(pool_size=(2,2)))

#converting multi dimension to 1 d array
model.add(Flatten())
model.add(Dense(units=150,activation='relu'))
model.add(Dropout(0.2))

#output layer
num_classes = len(train_data.class_indices)

model.add(Dense(units=num_classes, activation='softmax'))

print(model.summary())
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_9 (Conv2D)           (None, 148, 148, 32)      896
#
#  max_pooling2d_9 (MaxPoolin  (None, 74, 74, 32)        0
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 72, 72, 64)        18496
#
#  max_pooling2d_10 (MaxPooli  (None, 36, 36, 64)        0
#  ng2D)
#
#  conv2d_11 (Conv2D)          (None, 34, 34, 32)        18464
#
#  max_pooling2d_11 (MaxPooli  (None, 17, 17, 32)        0
#  ng2D)
#
#  flatten_3 (Flatten)         (None, 9248)              0
#
#  dense_5 (Dense)             (None, 150)               1387350
#
#  dropout_3 (Dropout)         (None, 150)               0
#
#  dense_6 (Dense)             (None, 2)                 302
#
# =================================================================
# Total params: 1425508 (5.44 MB)
# Trainable params: 1425508 (5.44 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
result=model.fit(train_data,
                 steps_per_epoch=48//batch_size,epochs=50,
                 validation_data=test_data,
                 validation_steps=48//batch_size)
# Out:
# Epoch 1/50
# 3/3 [==============================] - 2s 352ms/step - loss: 0.8246 - accuracy: 0.5417 - val_loss: 0.7817 - val_accuracy: 0.5000
# Epoch 2/50
# 3/3 [==============================] - 1s 303ms/step - loss: 0.7704 - accuracy: 0.4167 - val_loss: 0.7101 - val_accuracy: 0.5417
# Epoch 3/50
# 3/3 [==============================] - 1s 266ms/step - loss: 1.1243 - accuracy: 0.4583 - val_loss: 0.7000 - val_accuracy: 0.4167
# Epoch 4/50
# 3/3 [==============================] - 1s 271ms/step - loss: 0.7627 - accuracy: 0.4375 - val_loss: 0.7220 - val_accuracy: 0.4792
# Epoch 5/50
# 3/3 [==============================] - 1s 270ms/step - loss: 0.7130 - accuracy: 0.4167 - val_loss: 0.6934 - val_accuracy: 0.4375
# Epoch 6/50
# 3/3 [==============================] - 1s 267ms/step - loss: 0.8170 - accuracy: 0.4167 - val_loss: 0.6967 - val_accuracy: 0.4792
# Epoch 7/50
# 3/3 [==============================] - 1s 265ms/step - loss: 0.7525 - accuracy: 0.4375 - val_loss: 0.7139 - val_accuracy: 0.5208
# Epoch 8/50
# 3/3 [==============================] - 1s 257ms/step - loss: 0.7548 - accuracy: 0.4167 - val_loss: 0.6884 - val_accuracy: 0.5833
# Epoch 9/50
# 3/3 [==============================] - 1s 266ms/step - loss: 0.7006 - accuracy: 0.4792 - val_loss: 0.7040 - val_accuracy: 0.5000
# Epoch 10/50
# 3/3 [==============================] - 1s 266ms/step - loss: 0.6920 - accuracy: 0.5208 - val_loss: 0.7180 - val_accuracy: 0.4375
# Epoch 11/50
# 3/3 [==============================] - 1s 247ms/step - loss: 0.7131 - accuracy: 0.3750 - val_loss: 0.6842 - val_accuracy: 0.5417
# Epoch 12/50
# 3/3 [==============================] - 1s 263ms/step - loss: 0.6830 - accuracy: 0.5417 - val_loss: 0.6827 - val_accuracy: 0.5417
# Epoch 13/50
# 3/3 [==============================] - 1s 252ms/step - loss: 0.7012 - accuracy: 0.4792 - val_loss: 0.7056 - val_accuracy: 0.4792
# Epoch 14/50
# 3/3 [==============================] - 1s 267ms/step - loss: 0.7227 - accuracy: 0.3958 - val_loss: 0.7133 - val_accuracy: 0.4375
# Epoch 15/50
# 3/3 [==============================] - 1s 269ms/step - loss: 0.6720 - accuracy: 0.5833 - val_loss: 0.7024 - val_accuracy: 0.4583
# Epoch 16/50
# 3/3 [==============================] - 1s 269ms/step - loss: 0.6969 - accuracy: 0.5000 - val_loss: 0.6866 - val_accuracy: 0.5625
# Epoch 17/50
# 3/3 [==============================] - 1s 280ms/step - loss: 0.6853 - accuracy: 0.6458 - val_loss: 0.6881 - val_accuracy: 0.5208
# Epoch 18/50
# 3/3 [==============================] - 1s 303ms/step - loss: 0.6934 - accuracy: 0.5417 - val_loss: 0.6868 - val_accuracy: 0.5208
# Epoch 19/50
# 3/3 [==============================] - 1s 270ms/step - loss: 0.6804 - accuracy: 0.6042 - val_loss: 0.6830 - val_accuracy: 0.5625
# Epoch 20/50
# 3/3 [==============================] - 1s 274ms/step - loss: 0.6409 - accuracy: 0.6875 - val_loss: 0.9385 - val_accuracy: 0.4375
# Epoch 21/50
# 3/3 [==============================] - 1s 264ms/step - loss: 0.8308 - accuracy: 0.4792 - val_loss: 0.6840 - val_accuracy: 0.5208
# Epoch 22/50
# 3/3 [==============================] - 1s 265ms/step - loss: 0.6985 - accuracy: 0.4792 - val_loss: 0.6875 - val_accuracy: 0.5000
# Epoch 23/50
# 3/3 [==============================] - 1s 257ms/step - loss: 0.6714 - accuracy: 0.5417 - val_loss: 0.6742 - val_accuracy: 0.5625
# Epoch 24/50
# 3/3 [==============================] - 1s 266ms/step - loss: 0.7078 - accuracy: 0.4583 - val_loss: 0.6747 - val_accuracy: 0.5625
# Epoch 25/50
# 3/3 [==============================] - 1s 263ms/step - loss: 0.7136 - accuracy: 0.4583 - val_loss: 0.6733 - val_accuracy: 0.5625
# Epoch 26/50
# 3/3 [==============================] - 1s 266ms/step - loss: 0.6840 - accuracy: 0.6042 - val_loss: 0.6823 - val_accuracy: 0.5625
# Epoch 27/50
# 3/3 [==============================] - 1s 285ms/step - loss: 0.6828 - accuracy: 0.5208 - val_loss: 0.6876 - val_accuracy: 0.5208
# Epoch 28/50
# 3/3 [==============================] - 1s 361ms/step - loss: 0.7054 - accuracy: 0.3750 - val_loss: 0.6880 - val_accuracy: 0.4792
# Epoch 29/50
# 3/3 [==============================] - 1s 384ms/step - loss: 0.6978 - accuracy: 0.4167 - val_loss: 0.6886 - val_accuracy: 0.6458
# Epoch 30/50
# 3/3 [==============================] - 1s 394ms/step - loss: 0.6888 - accuracy: 0.5417 - val_loss: 0.6893 - val_accuracy: 0.5000
# Epoch 31/50
# 3/3 [==============================] - 1s 343ms/step - loss: 0.6915 - accuracy: 0.5208 - val_loss: 0.6919 - val_accuracy: 0.5208
# Epoch 32/50
# 3/3 [==============================] - 1s 343ms/step - loss: 0.6968 - accuracy: 0.4375 - val_loss: 0.6943 - val_accuracy: 0.4792
# Epoch 33/50
# 3/3 [==============================] - 1s 348ms/step - loss: 0.6925 - accuracy: 0.4792 - val_loss: 0.6985 - val_accuracy: 0.4792
# Epoch 34/50
# 3/3 [==============================] - 1s 339ms/step - loss: 0.6955 - accuracy: 0.5417 - val_loss: 0.6883 - val_accuracy: 0.5625
# Epoch 35/50
# 3/3 [==============================] - 1s 330ms/step - loss: 0.6907 - accuracy: 0.5208 - val_loss: 0.6873 - val_accuracy: 0.6042
# Epoch 36/50
# 3/3 [==============================] - 1s 350ms/step - loss: 0.6949 - accuracy: 0.5833 - val_loss: 0.6922 - val_accuracy: 0.5000
# Epoch 37/50
# 3/3 [==============================] - 1s 351ms/step - loss: 0.6991 - accuracy: 0.5000 - val_loss: 0.6883 - val_accuracy: 0.5208
# Epoch 38/50
# 3/3 [==============================] - 1s 337ms/step - loss: 0.6927 - accuracy: 0.4792 - val_loss: 0.6892 - val_accuracy: 0.5417
# Epoch 39/50
# 3/3 [==============================] - 1s 353ms/step - loss: 0.6869 - accuracy: 0.6458 - val_loss: 0.6850 - val_accuracy: 0.5833
# Epoch 40/50
# 3/3 [==============================] - 1s 361ms/step - loss: 0.6866 - accuracy: 0.6458 - val_loss: 0.6754 - val_accuracy: 0.6875
# Epoch 41/50
# 3/3 [==============================] - 1s 351ms/step - loss: 0.6974 - accuracy: 0.4167 - val_loss: 0.6793 - val_accuracy: 0.5833
# Epoch 42/50
# 3/3 [==============================] - 1s 348ms/step - loss: 0.6870 - accuracy: 0.6250 - val_loss: 0.6851 - val_accuracy: 0.5833
# Epoch 43/50
# 3/3 [==============================] - 1s 338ms/step - loss: 0.6863 - accuracy: 0.6250 - val_loss: 0.6787 - val_accuracy: 0.6458
# Epoch 44/50
# 3/3 [==============================] - 1s 342ms/step - loss: 0.6889 - accuracy: 0.5208 - val_loss: 0.6698 - val_accuracy: 0.5833
# Epoch 45/50
# 3/3 [==============================] - 1s 351ms/step - loss: 0.7020 - accuracy: 0.3958 - val_loss: 0.6782 - val_accuracy: 0.5625
# Epoch 46/50
# 3/3 [==============================] - 1s 338ms/step - loss: 0.6972 - accuracy: 0.5417 - val_loss: 0.6788 - val_accuracy: 0.7083
# Epoch 47/50
# 3/3 [==============================] - 1s 360ms/step - loss: 0.6993 - accuracy: 0.3750 - val_loss: 0.6814 - val_accuracy: 0.5417
# Epoch 48/50
# 3/3 [==============================] - 1s 334ms/step - loss: 0.7017 - accuracy: 0.4167 - val_loss: 0.6656 - val_accuracy: 0.6458
# Epoch 49/50
# 3/3 [==============================] - 1s 337ms/step - loss: 0.6920 - accuracy: 0.5417 - val_loss: 0.6789 - val_accuracy: 0.6042
# Epoch 50/50
# 3/3 [==============================] - 1s 349ms/step - loss: 0.6842 - accuracy: 0.5833 - val_loss: 0.6831 - val_accuracy: 0.5208

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

print(result.history.keys())

plt.plot(result.history['accuracy'])
plt.plot(result.history['val_accuracy'])
plt.title('Model Accuracy- Train Vs Test')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend(['Train','Test'])
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# # Plot for Train & Test Loss

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
print(result.history.keys())
plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('Model Loss- Train Vs Test')
plt.xlabel('epochs')
plt.ylabel('Loss')
plt.legend(['Train','Test'])
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
